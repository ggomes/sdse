# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab01.ipynb")

# %% [markdown]
# ---
#
# <h2><center>Demo for Jupyter Notebooks based exercises <br></center></h2>
#
# ---

# %%
from hashutils import *

# %% [markdown]
# # Part 1: A simple calculation
# Compute the area of a square with sides of length L=2 meters

# %%
L = 2.1
area = L**2

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Please submit the .zip file to Gradescope.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False)
# Out:
#                     <p>
#                         Your submission has been exported. Click
#                         <a href="lab01_2025_01_27T11_51_45_872102.zip" download="lab01_2025_01_27T11_51_45_872102.zip" target="_blank">here</a> to download
#                         the zip file.
#                     </p>
